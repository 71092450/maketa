# %%
import matplotlib.pyplot as plt

# %%
a = [7,12,15,20]#ejex
b = [20,15,10,5]#Eje y


values=(["Alumnos de ultimo año","Alumnos de tercer año","Alumnos de segundo año","Alumnos de primer año"])

plt.annotate("(12,10)",xy=(14,13)) 
plt.annotate("(19,8)",xy=(19,8))
plt.annotate("(4,20)",xy=(4,20))
plt.annotate("(9,15)",xy=(9,15))
plt.xticks(b,values)
plt.bar(b,a, color="blue", linewidth=4) 
plt.ylabel("Horas")
plt.title("Horas permitidas para los trabajos de medio tiempo")    
 
plt.grid()
plt.show()

# %%
nombres = ["Comedia 4(20%)","Ciencia ficcion 4(20%)","Drama 1(5%)","Romance 6(20%)","Accion 5(25%)"]
         
colores = ["orange","c","blue","r","blue"]


plt.pie(piña, labels=nombres,colors=colores)
plt.title("Tipo de pelicula favorito " )

        
plt.show()
